# %%
import numpy as np
import pandas as pd
import torchvision
import torch
import matplotlib.pyplot as plt
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler
from torch import nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from scipy.integrate import solve_ivp
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4348/2705955564.py in <module>
#      15 from scipy.integrate import odeint
#      16 from scipy.integrate import solve_ivp
# ---> 17 import cv2
#      18 import matplotlib.pyplot as plt
#      19 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import torch

# %%
def HR(self, X):
    x, y, z = X
    return [y - x**3 + b*x**2 + I - z,
            1 - 5*x**2 - y,
            mu*(s*(x-x_rest) - z)]

# %%
s = 4
mu = 0.01
x_rest = -1.6

# %%
img = cv2.imread('2021-10-11_13-49-10.png')
plt.figure(figsize=(10, 7))
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # 1 область

# %%
b = 0.5
I = 5.6
sol1 = solve_ivp(HR, [0, 20000], [-0.1, 0.1, -0.1], 
                t_eval=np.array(range(0, 20000, 1)), rtol = 1e-11, atol = 1e-11, dense_output=True)

# %%
plt.plot(sol1.t, sol1.y[0])

# %%
np.save('Area1', sol1.y)

# %% [markdown]
# # 2 область

# %%
b = 2
I = 5.6
sol2 = solve_ivp(HR, [0, 20000], [-0.1, 0.1, -0.1], 
                t_eval=np.array(range(0, 20000, 1)), rtol = 1e-11, atol = 1e-11, dense_output=True)

# %%
plt.plot(sol2.t, sol2.y[0])

# %%
np.save('HRData/Area2', sol2.y)

# %% [markdown]
# # 3 область

# %%
b = 3.1
I = 5.6
sol3 = solve_ivp(HR, [0, 20000], [-0.1, 0.1, -0.1], 
                t_eval=np.array(range(0, 20000, 1)), rtol = 1e-11, atol = 1e-11, dense_output=True)

# %%
plt.plot(sol3.y[0])

# %%
np.save('HRData/Area3', sol3.y)

# %% [markdown]
# # 4 область

# %%
b = 0.5
I = 5
sol4 = solve_ivp(HR, [0, 20000], [-0.1, 0.1, -0.1], 
                t_eval=np.array(range(0, 20000, 1)), rtol = 1e-11, atol = 1e-11, dense_output=True)

# %%
plt.plot(sol4.y[0])

# %%
np.save('HRData/Area4', sol4.y)

# %% [markdown]
# # 5 область

# %%
b = 2
I = 3
sol5 = solve_ivp(HR, [0, 20000], [-0.1, 0.1, -0.1], 
                t_eval=np.array(range(0, 20000, 1)), rtol = 1e-11, atol = 1e-11, dense_output=True)

# %%
plt.plot(sol5.y[0])

# %%
np.save('HRData/Area5', sol5.y)

# %% [markdown]
# # 6 область

# %%
b = 2.8
I = 5
sol6 = solve_ivp(HR, [0, 20000], [-0.1, 0.1, -0.1], 
                t_eval=np.array(range(0, 20000, 1)), rtol = 1e-11, atol = 1e-11, dense_output=True)

# %%
plt.plot(sol6.y[0])

# %%
np.save('HRData/Area6', sol6.y)

# %% [markdown]
# # 7 область

# %%
b = 3.5
I = 4
sol7 = solve_ivp(HR, [0, 20000], [-0.1, 0.1, -0.1], 
                t_eval=np.array(range(0, 20000, 1)), rtol = 1e-11, atol = 1e-11, dense_output=True)

# %%
plt.plot(sol7.y[0])

# %%
np.save('HRData/Area7', sol7.y)

# %% [markdown]
# # 8 область

# %%
b = 2.65
I = 3.6
sol8 = solve_ivp(HR, [0, 20000], [-0.1, 0.1, -0.1], 
                t_eval=np.array(range(0, 20000, 1)), rtol = 1e-11, atol = 1e-11, dense_output=True)

# %%
plt.plot(sol8.y[0])

# %%
np.save('HRData/Area8', sol8.y)

# %% [markdown]
# # 9 область

# %%
b = 4.5
I = 1.5
sol9 = solve_ivp(HR, [0, 20000], [-0.1, 0.1, -0.1], 
                t_eval=np.array(range(0, 20000, 1)), rtol = 1e-11, atol = 1e-11, dense_output=True)

# %%
plt.plot(sol9.y[0])

# %%
np.save('HRData/Area9', sol9.y)

# %% [markdown]
# # Серая область

# %%
b = 4.5
I = 1.5
sol10 = solve_ivp(HR, [0, 20000], [-0.3, 0.2, -0.1], 
                t_eval=np.array(range(0, 20000, 1)), rtol = 1e-11, atol = 1e-11, dense_output=True)

# %%
plt.plot(sol10.y[0])

# %%
np.save('HRData/Area10', sol10.y)

# %% [markdown]
# # Параметры Егора

# %%
mu = 0.0021
b = 3
I = 3.295
sol11 = solve_ivp(HR, [0, 20000], [-0.3, 0.2, -0.1], 
                t_eval=np.array(range(0, 20000, 1)), rtol = 1e-11, atol = 1e-11, dense_output=True)

# %%
plt.plot(sol11.y[0])

# %%
np.save('HRData/Area11', sol11.y)

# %%
mu = 0.0021
b = 3
I = 3.295
sol12 = solve_ivp(HR, [0, 20000], [-0.1, 0.1, -0.1], 
                t_eval=np.array(range(0, 20000, 1)), rtol = 1e-11, atol = 1e-11, dense_output=True)

# %%
plt.plot(sol12.y[0])

# %%
np.save('HRData/Area12', sol12.y)

# %%
b = 2.85
I = 3.75
sol13 = solve_ivp(HR, [0, 20000], [-0.1, 0.1, -0.1], 
                t_eval=np.array(range(0, 20000, 1)), rtol = 1e-11, atol = 1e-11, dense_output=True)

# %%
plt.plot(sol13.y[0])

# %%
np.save('HRData/Area13', sol13.y)

# %%
b = 2.925
I = 3.375
sol14 = solve_ivp(HR, [0, 20000], [-0.1, 0.1, -0.1], 
                t_eval=np.array(range(0, 20000, 1)), rtol = 1e-11, atol = 1e-11, dense_output=True)

# %%
plt.plot(sol14.y[0])

# %%
np.save('HRData/Area14', sol14.y)

# %%
b = 2.85
I = 3.3
sol15 = solve_ivp(HR, [0, 20000], [-0.1, 0.1, -0.1], 
                t_eval=np.array(range(0, 20000, 1)), rtol = 1e-11, atol = 1e-11, dense_output=True)

# %%
plt.plot(sol15.y[0])

# %%
np.save('HRData/Area15', sol15.y)

# %%
b = 2.9
I = 3.6
sol16 = solve_ivp(HR, [0, 20000], [-0.1, 0.1, -0.1], 
                t_eval=np.array(range(0, 20000, 1)), rtol = 1e-11, atol = 1e-11, dense_output=True)

# %%
plt.plot(sol16.y[0])

# %%
np.save('HRData/Area16', sol16.y)

# %% [markdown]
# # 3 5 6 7

# %%
trainx3 = np.load('HRData/Area3.npy')[0][:15000]
trainx5 = np.load('HRData/Area5.npy')[0][:15000]
trainx6 = np.load('HRData/Area6.npy')[0][:15000]
trainx7 = np.load('HRData/Area7.npy')[0][:15000]
traingr1 = np.load('HRData/Area11.npy')[0][:15000]
traingr2 = np.load('HRData/Area12.npy')[0][:15000]

testx3 = np.load('HRData/Area3.npy')[0][15000:]
testx5 = np.load('HRData/Area5.npy')[0][15000:]
testx6 = np.load('HRData/Area6.npy')[0][15000:]
testx7 = np.load('HRData/Area7.npy')[0][15000:]
testgr1 = np.load('HRData/Area11.npy')[0][15000:]
testgr2 = np.load('HRData/Area12.npy')[0][15000:]

# %%
plt.plot(trainx3)

# %%
mean = np.array([trainx3, trainx5, trainx6, trainx7, traingr1, traingr2]).mean()
std = np.array([trainx3, trainx5, trainx6, trainx7, traingr1, traingr2]).std()

# %%
trainx3 = (trainx3 - mean)/std
trainx5 = (trainx5 - mean)/std
trainx6 = (trainx6 - mean)/std
trainx7 = (trainx7 - mean)/std
traingr1 = (traingr1 - mean)/std
traingr2 = (traingr2 - mean)/std

testx3 = (testx3 - mean)/std
testx5 = (testx5 - mean)/std
testx6 = (testx6 - mean)/std
testx7 = (testx7 - mean)/std
testgr1 = (testgr1 - mean)/std
testgr2 = (testgr2 - mean)/std
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17776/1643518583.py in <module>
# ----> 1 trainx3 = (trainx3 - mean)/std
#       2 trainx5 = (trainx5 - mean)/std
#       3 trainx6 = (trainx6 - mean)/std
#       4 trainx7 = (trainx7 - mean)/std
#       5 traingr1 = (traingr1 - mean)/std
#
# NameError: name 'trainx3' is not defined

# %%
trainx3 = torch.FloatTensor(trainx3).view(-1)
trainx5 = torch.FloatTensor(trainx5).view(-1)
trainx6 = torch.FloatTensor(trainx6).view(-1)
trainx7 = torch.FloatTensor(trainx7).view(-1)
traingr1 = torch.FloatTensor(traingr1).view(-1)
traingr2 = torch.FloatTensor(traingr2).view(-1)

testx3 = torch.FloatTensor(testx3).view(-1)
testx5 = torch.FloatTensor(testx5).view(-1)
testx6 = torch.FloatTensor(testx6).view(-1)
testx7 = torch.FloatTensor(testx7).view(-1)
testgr1 = torch.FloatTensor(testgr1).view(-1)
testgr2 = torch.FloatTensor(testgr2).view(-1)

# %%
train_window = 20

def create_inout_sequences(input_data, tw):
    inout_seq = []
    L = len(input_data)
    for i in range(L-tw):
        train_seq = input_data[i:i+tw]
        train_label = input_data[i+tw:i+tw+1]
        inout_seq.append((train_seq ,train_label))
    return inout_seq

# %%
train_inout_seq = create_inout_sequences(trainx3, train_window)
test_inout_seq = create_inout_sequences(testx3, train_window)

# %%
train_inout_seq += create_inout_sequences(trainx5, train_window)
train_inout_seq += create_inout_sequences(trainx6, train_window)
train_inout_seq += create_inout_sequences(trainx7, train_window)
train_inout_seq += create_inout_sequences(traingr1, train_window)
train_inout_seq += create_inout_sequences(traingr2, train_window)

# %%
test_inout_seq += create_inout_sequences(testx5, train_window)
test_inout_seq += create_inout_sequences(testx6, train_window)
test_inout_seq += create_inout_sequences(testx7, train_window)
test_inout_seq += create_inout_sequences(testgr1, train_window)
test_inout_seq += create_inout_sequences(testgr2, train_window)

# %%
len(train_inout_seq)
# Out:
# 89880

# %%
class LSTMModel(nn.Module):
    def __init__(self, input_size=1, hidden_layer_size=32, num_layers=2, output_size=1, dropout=0.2):
        super().__init__()
        self.hidden_layer_size = hidden_layer_size

        self.linear_1 = nn.Linear(input_size, hidden_layer_size)
        self.relu = nn.ReLU()
        self.lstm = nn.LSTM(hidden_layer_size, hidden_size=self.hidden_layer_size, num_layers=num_layers, batch_first=True)
        self.dropout = nn.Dropout(dropout)
        self.linear_2 = nn.Linear(num_layers*hidden_layer_size, output_size)
        
        self.init_weights()

    def init_weights(self):
        for name, param in self.lstm.named_parameters():
            if 'bias' in name:
                 nn.init.constant_(param, 0.0)
            elif 'weight_ih' in name:
                 nn.init.kaiming_normal_(param)
            elif 'weight_hh' in name:
                 nn.init.orthogonal_(param)

    def forward(self, x):
        batchsize = x.shape[0]

        # layer 1
        x = self.linear_1(x)
        x = self.relu(x)
        
        # LSTM layer
        lstm_out, (h_n, c_n) = self.lstm(x)

        # reshape output from hidden cell into [batch, features] for `linear_2`
        x = h_n.permute(1, 0, 2).reshape(batchsize, -1) 
        
        # layer 2
        x = self.dropout(x)
        predictions = self.linear_2(x)
        return predictions[:,-1]

# %%
from torch.utils.data import DataLoader

# %%
train_dataloader = DataLoader(train_inout_seq, batch_size=64, shuffle=True, drop_last=True)
test_dataloader = DataLoader(test_inout_seq, batch_size=64, shuffle=True, drop_last=True)

# %%
for x, y in train_dataloader:
    print(torch.reshape(x, (64, 20, 1)).size())
    print(y.view(-1).size())
    break
# Out:
# torch.Size([64, 20, 1])
# torch.Size([64])

# %%
model = LSTMModel(input_size=1, hidden_layer_size=100, num_layers=2, output_size=1, dropout=0.2)
model = model.to('cuda')

# %%
from IPython.display import clear_output

# %%
def run_epoch(dataloader, is_training=False):
    epoch_loss = 0

    if is_training:
        model.train()
    else:
        model.eval()

    for idx, (x, y) in enumerate(dataloader):
        if is_training:
            optimizer.zero_grad()

        batchsize = x.shape[0]

        x = torch.reshape(x, (64, 20, 1)).to('cuda')
        y = y.view(-1).to('cuda')

        out = model(x)
        loss = criterion(out.contiguous(), y.contiguous())

        if is_training:
            loss.backward()
            optimizer.step()

        epoch_loss += (loss.detach().item() / batchsize)


    return epoch_loss

# define optimizer, scheduler and loss function
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, betas=(0.9, 0.98), eps=1e-9)
#scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=40, gamma=0.1)
lr = 0.001

losses_train = []
losses_test = []
# begin training
for epoch in range(200): 
    if epoch > 40:
        lr = 0.0001
    if epoch > 100:
        lr = 0.00001
    optimizer = optim.Adam(model.parameters(), lr=lr, betas=(0.9, 0.98), eps=1e-9)    
    loss_train = run_epoch(train_dataloader, is_training=True)
    loss_val = run_epoch(test_dataloader)
    losses_train.append(loss_train)
    losses_test.append(loss_val)
    
    clear_output(True)
    fig = plt.figure(figsize=(10, 9))
    
    ax_1 = fig.add_subplot(2, 1, 1)
    ax_2 = fig.add_subplot(2, 1, 2)
    ax_1.set_title('train')
    ax_1.plot(losses_train)
    ax_2.set_title('test')
    ax_2.plot(losses_test)
    plt.show()
    
    print('Epoch[{}/{}] | loss train:{:.6f}, test:{:.6f}'
              .format(epoch+1, 200, loss_train, loss_val))
# Out:
# Epoch[200/200] | loss train:0.031421, test:0.000057

# %%
train_inout_seq3 = create_inout_sequences(trainx3, train_window)
test_inout_seq3 = create_inout_sequences(testx3, train_window)
train_dataloader = DataLoader(train_inout_seq3, batch_size=64, shuffle=False, drop_last=True)
val_dataloader = DataLoader(test_inout_seq3, batch_size=64, shuffle=False, drop_last=True)

model.eval()

# predict on the training data, to see how well the model managed to learn and memorize

predicted_train3 = np.array([])

for idx, (x, y) in enumerate(train_dataloader):
    x = torch.reshape(x, (64, 20, 1)).to('cuda')
    out = model(x)
    out = out.cpu().detach().numpy()
    predicted_train3 = np.concatenate((predicted_train3, out))

# predict on the validation data, to see how the model does

predicted_val3 = np.array([])

for idx, (x, y) in enumerate(val_dataloader):
    x = torch.reshape(x, (64, 20, 1)).to('cuda')
    out = model(x)
    out = out.cpu().detach().numpy()
    predicted_val3 = np.concatenate((predicted_val3, out))

# %%
plt.plot(predicted_train3[200:500])

# %%
plt.plot(trainx3[220:520])

# %%
plt.plot(predicted_val3[200:500])

# %%
plt.plot(testx3[220:520])

# %%
train_inout_seq5 = create_inout_sequences(trainx5, train_window)
test_inout_seq5 = create_inout_sequences(testx5, train_window)
train_dataloader = DataLoader(train_inout_seq5, batch_size=64, shuffle=False, drop_last=True)
val_dataloader = DataLoader(test_inout_seq5, batch_size=64, shuffle=False, drop_last=True)

model.eval()

# predict on the training data, to see how well the model managed to learn and memorize

predicted_train5 = np.array([])

for idx, (x, y) in enumerate(train_dataloader):
    x = torch.reshape(x, (64, 20, 1)).to('cuda')
    out = model(x)
    out = out.cpu().detach().numpy()
    predicted_train5 = np.concatenate((predicted_train5, out))

# predict on the validation data, to see how the model does

predicted_val5 = np.array([])

for idx, (x, y) in enumerate(val_dataloader):
    x = torch.reshape(x, (64, 20, 1)).to('cuda')
    out = model(x)
    out = out.cpu().detach().numpy()
    predicted_val5 = np.concatenate((predicted_val5, out))

# %%
plt.plot(predicted_train5[200:500])

# %%
plt.plot(trainx5[220:520])

# %%
plt.plot(predicted_val5[200:500])

# %%
plt.plot(testx5[220:520])

# %%
train_inout_seq6 = create_inout_sequences(trainx6, train_window)
test_inout_seq6 = create_inout_sequences(testx6, train_window)
train_dataloader = DataLoader(train_inout_seq6, batch_size=64, shuffle=False, drop_last=True)
val_dataloader = DataLoader(test_inout_seq6, batch_size=64, shuffle=False, drop_last=True)

model.eval()

# predict on the training data, to see how well the model managed to learn and memorize

predicted_train6 = np.array([])

for idx, (x, y) in enumerate(train_dataloader):
    x = torch.reshape(x, (64, 20, 1)).to('cuda')
    out = model(x)
    out = out.cpu().detach().numpy()
    predicted_train6 = np.concatenate((predicted_train6, out))

# predict on the validation data, to see how the model does

predicted_val6 = np.array([])

for idx, (x, y) in enumerate(val_dataloader):
    x = torch.reshape(x, (64, 20, 1)).to('cuda')
    out = model(x)
    out = out.cpu().detach().numpy()
    predicted_val6 = np.concatenate((predicted_val6, out))

# %%
plt.plot(predicted_train6[200:500])

# %%
plt.plot(trainx6[220:520])

# %%
plt.plot(predicted_val6[200:500])

# %%
plt.plot(testx6[220:520])

# %%
train_inout_seq7 = create_inout_sequences(trainx7, train_window)
test_inout_seq7 = create_inout_sequences(testx7, train_window)
train_dataloader = DataLoader(train_inout_seq7, batch_size=64, shuffle=False, drop_last=True)
val_dataloader = DataLoader(test_inout_seq7, batch_size=64, shuffle=False, drop_last=True)

model.eval()

# predict on the training data, to see how well the model managed to learn and memorize

predicted_train7 = np.array([])

for idx, (x, y) in enumerate(train_dataloader):
    x = torch.reshape(x, (64, 20, 1)).to('cuda')
    out = model(x)
    out = out.cpu().detach().numpy()
    predicted_train7 = np.concatenate((predicted_train7, out))

# predict on the validation data, to see how the model does

predicted_val7 = np.array([])

for idx, (x, y) in enumerate(val_dataloader):
    x = torch.reshape(x, (64, 20, 1)).to('cuda')
    out = model(x)
    out = out.cpu().detach().numpy()
    predicted_val7 = np.concatenate((predicted_val7, out))

# %%
plt.plot(predicted_train7[200:500])

# %%
plt.plot(trainx7[220:520])

# %%
plt.plot(predicted_val7[200:500])

# %%
plt.plot(testx7[220:520])

# %%
train_inout_seq11 = create_inout_sequences(traingr1, train_window)
test_inout_seq11 = create_inout_sequences(testgr1, train_window)
train_dataloader = DataLoader(train_inout_seq11, batch_size=64, shuffle=False, drop_last=True)
val_dataloader = DataLoader(test_inout_seq11, batch_size=64, shuffle=False, drop_last=True)

model.eval()

# predict on the training data, to see how well the model managed to learn and memorize

predicted_train11 = np.array([])

for idx, (x, y) in enumerate(train_dataloader):
    x = torch.reshape(x, (64, 20, 1)).to('cuda')
    out = model(x)
    out = out.cpu().detach().numpy()
    predicted_train11 = np.concatenate((predicted_train11, out))

# predict on the validation data, to see how the model does

predicted_val11 = np.array([])

for idx, (x, y) in enumerate(val_dataloader):
    x = torch.reshape(x, (64, 20, 1)).to('cuda')
    out = model(x)
    out = out.cpu().detach().numpy()
    predicted_val11 = np.concatenate((predicted_val11, out))

# %%
plt.plot(predicted_train11[200:500])

# %%
plt.plot(traingr1[220:520])

# %%
plt.plot(predicted_val11[200:500])

# %%
plt.plot(testgr1[220:520])

# %%
train_inout_seq12 = create_inout_sequences(traingr2, train_window)
test_inout_seq12 = create_inout_sequences(testgr2, train_window)
train_dataloader = DataLoader(train_inout_seq12, batch_size=64, shuffle=False, drop_last=True)
val_dataloader = DataLoader(test_inout_seq12, batch_size=64, shuffle=False, drop_last=True)

model.eval()

# predict on the training data, to see how well the model managed to learn and memorize

predicted_train12 = np.array([])

for idx, (x, y) in enumerate(train_dataloader):
    x = torch.reshape(x, (64, 20, 1)).to('cuda')
    out = model(x)
    out = out.cpu().detach().numpy()
    predicted_train12 = np.concatenate((predicted_train12, out))

# predict on the validation data, to see how the model does

predicted_val12 = np.array([])

for idx, (x, y) in enumerate(val_dataloader):
    x = torch.reshape(x, (64, 20, 1)).to('cuda')
    out = model(x)
    out = out.cpu().detach().numpy()
    predicted_val12 = np.concatenate((predicted_val12, out))

# %%
plt.plot(predicted_train11[200:500])

# %%
plt.plot(traingr1[220:520])

# %%
plt.plot(predicted_val11[200:500])

# %%
plt.plot(testgr1[220:520])
