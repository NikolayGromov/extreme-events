# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
loaded_data = np.load("predicts/all201_matrices_predicts.npz")
all_matrices_predicts = [loaded_data[f'arr_{i}'] for i in range(len(loaded_data.files))]

# %%
fig = plt.figure(figsize=(16, 9))
ax = fig.add_subplot(projection='3d')
ax.plot(all_matrices_predicts[0][21][6000:, 0], all_matrices_predicts[0][21][6000:, 1], all_matrices_predicts[0][21][6000:, 2], color="blue")

ax.set_xlabel("x", size=30, labelpad=20)
ax.set_ylabel("y", size=30, labelpad=20)
ax.set_zlabel("z", size=30, labelpad=-30)

ax.tick_params(axis='both', which='major', labelsize=30)

plt.tight_layout()

# %%
all_matrices_predicts[0][21][-1]
# Out:
# array([  0.51046403, -16.49603222, -30.50015543,  14.69162024])

# %%
plt.plot(all_matrices_predicts[0][21][:, 0])
