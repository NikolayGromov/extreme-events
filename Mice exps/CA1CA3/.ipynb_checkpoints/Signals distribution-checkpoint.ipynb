# %%
import numpy as np
import os
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
ca1_0 = []
ca1_1 = []
ca1_2 = []
ca1_3 = []
ca1_4 = []
ca1_5 = []

ca3_0 = []
ca3_1 = []
ca3_2 = []
ca3_3 = []
ca3_4 = []
ca3_5 = []

for filename in os.listdir("./data_intersec"):
    if "ca1_0" in filename:
        ca1_0.append(np.load("./data_intersec/" + filename))
    if "ca1_1" in filename:
        ca1_1.append(np.load("./data_intersec/" + filename))
    if "ca1_2" in filename:
        ca1_2.append(np.load("./data_intersec/" + filename))
    if "ca1_3" in filename:
        ca1_3.append(np.load("./data_intersec/" + filename))
    if "ca1_4" in filename:
        ca1_4.append(np.load("./data_intersec/" + filename))
    if "ca1_5" in filename:
        ca1_5.append(np.load("./data_intersec/" + filename))
        
        
    if "ca3_0" in filename:
        ca3_0.append(np.load("./data_intersec/" + filename))
    if "ca3_1" in filename:
        ca3_1.append(np.load("./data_intersec/" + filename))
    if "ca3_2" in filename:
        ca3_2.append(np.load("./data_intersec/" + filename))
    if "ca3_3" in filename:
        ca3_3.append(np.load("./data_intersec/" + filename))
    if "ca3_4" in filename:
        ca3_4.append(np.load("./data_intersec/" + filename))
    if "ca3_5" in filename:
        ca3_5.append(np.load("./data_intersec/" + filename))

# %%
path = "./data_non_intersec/"
for filename in os.listdir(path):
    if "ca1_0" in filename:
        ca1_0.append(np.load(path + filename))
    if "ca1_1" in filename:
        ca1_1.append(np.load(path + filename))
    if "ca1_2" in filename:
        ca1_2.append(np.load(path + filename))
    if "ca1_3" in filename:
        ca1_3.append(np.load(path + filename))
    if "ca1_4" in filename:
        ca1_4.append(np.load(path + filename))
    if "ca1_5" in filename:
        ca1_5.append(np.load(path + filename))
        
        
    if "ca3_0" in filename:
        ca3_0.append(np.load(path + filename))
    if "ca3_1" in filename:
        ca3_1.append(np.load(path + filename))
    if "ca3_2" in filename:
        ca3_2.append(np.load(path + filename))
    if "ca3_3" in filename:
        ca3_3.append(np.load(path + filename))
    if "ca3_4" in filename:
        ca3_4.append(np.load(path + filename))
    if "ca3_5" in filename:
        ca3_5.append(np.load(path + filename))

# %%
def gausFilter(signal, sigma = 35):
    min1 = np.min(signal)
    gf = gaussian_filter(signal, sigma)
    min2 = np.min(gf)
    return gf*min1/min2

# %%
for signals in [ca1_0, ca1_1, ca1_2, ca1_3, ca1_4, ca1_5, ca3_0, ca3_1, ca3_2, ca3_3, ca3_4, ca3_5]:
    for i in range(len(signals)):
        signals[i] = gausFilter(signals[i])

# %%
key_points = []
for i, signals in enumerate([ca1_0, ca1_1, ca1_2, ca1_3, ca1_4, ca1_5, ca3_0, ca3_1, ca3_2, ca3_3, ca3_4, ca3_5]):
    cur_key_points = []
    for i in range(len(signals)):
        borders = getAnswer(signals[i])
        minima = np.min(signals[i])
        point = [signals[i][4000]] + [signals[i][8000]] + [minima]
        cur_key_points.append(point)
    key_points.append(cur_key_points)

# %%
for i in range(len(key_points)):
    key_points[i] = np.array(key_points[i])

# %% [markdown]
# ### MINIMUMS

# %%
ca1_names = ["ca1_100", "ca1_200", "ca1_300", "ca1_400", "ca1_500", "ca1_1000"]
ca3_names = ["ca3_100", "ca3_200", "ca3_300", "ca3_400", "ca3_500", "ca3_1000"]

# %%
fig = plt.figure(figsize=(16, 9))
for i, cur_key_points in enumerate(ca1_names):
    plt.plot(np.sort(key_points[i][:, 2]), np.linspace(0, 1, len(key_points[i][:, 2]), endpoint=False), label=cur_key_points)
plt.legend(fontsize = 16)

# %%
fig = plt.figure(figsize=(16, 9))
for i, cur_key_points in enumerate(ca1_names):
    sns.distplot(np.sort(key_points[i][:, 2]), hist=False, kde=True, 
             bins=50, label=cur_key_points)
plt.legend(fontsize = 16)

# %%
fig = plt.figure(figsize=(16, 9))
for i, cur_key_points in enumerate(ca3_names):
    plt.plot(np.sort(key_points[6+i][:, 2]), np.linspace(0, 1, len(key_points[6+i][:, 2]), endpoint=False), label=cur_key_points)
plt.legend(fontsize = 16)

# %%
fig = plt.figure(figsize=(16, 9))
for i, cur_key_points in enumerate(ca3_names):
    sns.distplot(np.sort(key_points[6+i][:, 2]), hist=False, kde=True, 
             bins=50, label=cur_key_points)
plt.legend(fontsize = 16)

# %% [markdown]
# ### Noise points

# %%
fig = plt.figure(figsize=(16, 9))
for i, cur_key_points in enumerate(ca1_names):
    plt.plot(np.sort(key_points[i][:, 0]), np.linspace(0, 1, len(key_points[i][:, 0]), endpoint=False), label=cur_key_points)
plt.legend(fontsize = 16)

# %%
fig = plt.figure(figsize=(16, 9))
for i, cur_key_points in enumerate(ca1_names):
    sns.distplot(np.sort(key_points[i][:, 0]), hist=False, kde=True, 
             bins=50, label=cur_key_points)
plt.legend(fontsize = 16)

# %%
fig = plt.figure(figsize=(16, 9))
for i, cur_key_points in enumerate(ca3_names):
    plt.plot(np.sort(key_points[6+i][:, 0]), np.linspace(0, 1, len(key_points[6+i][:, 0]), endpoint=False), label=cur_key_points)
plt.legend(fontsize = 16)

# %%
fig = plt.figure(figsize=(16, 9))
for i, cur_key_points in enumerate(ca3_names):
    sns.distplot(np.sort(key_points[6+i][:, 0]), hist=False, kde=True, 
             bins=50, label=cur_key_points)
plt.legend(fontsize = 16)

# %%
fig = plt.figure(figsize=(16, 9))
for i, cur_key_points in enumerate(ca1_names):
    plt.plot(np.sort(key_points[i][:, 1]), np.linspace(0, 1, len(key_points[i][:, 1]), endpoint=False), label=cur_key_points)
plt.legend(fontsize = 16)

# %%
fig = plt.figure(figsize=(16, 9))
for i, cur_key_points in enumerate(ca1_names):
    sns.distplot(np.sort(key_points[i][:, 1]), hist=False, kde=True, 
             bins=50, label=cur_key_points)
plt.legend(fontsize = 16)

# %%
fig = plt.figure(figsize=(16, 9))
for i, cur_key_points in enumerate(ca3_names):
    plt.plot(np.sort(key_points[6+i][:, 1]), np.linspace(0, 1, len(key_points[6+i][:, 1]), endpoint=False), label=cur_key_points)
plt.legend(fontsize = 16)

# %%
fig = plt.figure(figsize=(16, 9))
for i, cur_key_points in enumerate(ca3_names):
    sns.distplot(np.sort(key_points[6+i][:, 1]), hist=False, kde=True, 
             bins=50, label=cur_key_points)
plt.legend(fontsize = 16)

# %% [markdown]
# ### Drafts

# %% [markdown]
# Minimum

# %%
fig = plt.figure(figsize=(9, 80))
for i, cur_key_points in enumerate(["ca1_100", "ca1_200", "ca1_300", "ca1_400", "ca1_500", "ca1_1000", 
                                    "ca3_100", "ca3_200", "ca3_300", "ca3_400", "ca3_500", "ca3_1000"]):
    
    ax = fig.add_subplot(len(key_points), 1, i+1)
    ax.plot(np.sort(key_points[i][:, 2]), np.linspace(0, 1, len(key_points[i][:, 2]), endpoint=False))
    ax.set_title(cur_key_points)

# %% [markdown]
# Ca3 plots

# %%
fig = plt.figure(figsize=(9, 80))
for i in range(len(ca3_2)):
    
    ax = fig.add_subplot(len(ca3_2), 1, i+1)
    ax.plot(ca3_2[i])

# %%
fig = plt.figure(figsize=(9, 80))
for i in range(len(ca3_1)):
    
    ax = fig.add_subplot(len(ca3_1), 1, i+1)
    ax.plot(ca3_1[i])

# %%
fig = plt.figure(figsize=(16, 9))
for i, cur_key_points in enumerate(ca3_names):
    plt.hist(np.sort(key_points[6+i][:, 1]), bins=50, label=cur_key_points)
plt.legend(fontsize = 16)
