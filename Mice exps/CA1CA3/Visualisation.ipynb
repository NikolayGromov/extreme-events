# %%
import numpy as np
import torchvision
import torch
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler
from torch import nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
import math
from IPython.display import clear_output
from tqdm import tqdm
from scipy.ndimage import gaussian_filter
import scipy.signal as sps
import matplotlib.ticker as ticker
import pandas as pd
import scipy.io
# %matplotlib inline

# %%
ca3 = scipy.io.loadmat('./ЛПП мышей/Без разрушения исходники/3_06_2022 21 h 100.mat')

# %%
ca3['Trace_1_9_1_1'].shape
# Out:
# (11202, 2)

# %%
ca3['Trace_1_9_1_2'].shape
# Out:
# (11202, 2)

# %%
ca3['Trace_1_9_1_3'].shape
# Out:
# (11202, 2)

# %%
fig = plt.figure(figsize=(10, 9))
    
ax_1 = fig.add_subplot(3, 1, 1)
ax_2 = fig.add_subplot(3, 1, 2)
ax_3 = fig.add_subplot(3, 1, 3)

ax_1.plot(ca3['Trace_1_9_1_1'][:, 1])
ax_2.plot(ca3['Trace_1_9_1_2'][:, 1])
ax_3.plot(ca3['Trace_1_9_1_3'][:, 1])

plt.show()

# %%
fig = plt.figure(figsize=(10, 9))
    
ax_1 = fig.add_subplot(3, 1, 1)
ax_2 = fig.add_subplot(3, 1, 2)
ax_3 = fig.add_subplot(3, 1, 3)

ax_1.plot(ca3['Trace_1_9_1_1'][:, 1][:1000])
ax_2.plot(ca3['Trace_1_9_1_2'][:, 1][:1000])
ax_3.plot(ca3['Trace_1_9_1_3'][:, 1][:1000])

plt.show()

# %%
exp2 = scipy.io.loadmat('./ЛПП мышей/Без разрушения исходники/13_04_2022 1 tr5 healthy 100.mat')

# %%
fig = plt.figure(figsize=(10, 9))
    
ax_1 = fig.add_subplot(3, 1, 1)
ax_2 = fig.add_subplot(3, 1, 2)
ax_3 = fig.add_subplot(3, 1, 3)

ax_1.plot(exp2['Trace_1_5_1_1'][:, 1])
ax_2.plot(exp2['Trace_1_5_1_2'][:, 1])
ax_3.plot(exp2['Trace_1_5_1_3'][:, 1])

plt.show()

# %%
exp3 = scipy.io.loadmat('./ЛПП мышей/Без разрушения исходники/100/3_06_2022 22 h 100.mat')

# %%
fig = plt.figure(figsize=(10, 9))
    
ax_1 = fig.add_subplot(3, 1, 1)
ax_2 = fig.add_subplot(3, 1, 2)
ax_3 = fig.add_subplot(3, 1, 3)

ax_1.plot(exp3['Trace_1_11_1_1'][:, 1])
ax_2.plot(exp3['Trace_1_11_1_2'][:, 1])
ax_3.plot(exp3['Trace_1_11_1_3'][:, 1])

plt.show()

# %%
exp4 = scipy.io.loadmat('./ЛПП мышей/Без разрушения исходники/100/25_04_2022 17 tr1 healthy 100.mat')

# %%
fig = plt.figure(figsize=(10, 9))
    
ax_1 = fig.add_subplot(3, 1, 1)
ax_2 = fig.add_subplot(3, 1, 2)
ax_3 = fig.add_subplot(3, 1, 3)

ax_1.plot(exp4['Trace_1_1_1_1'][:, 1])
ax_2.plot(exp4['Trace_1_1_1_2'][:, 1])
ax_3.plot(exp4['Trace_1_1_1_3'][:, 1])

plt.show()

# %%
exp5 = scipy.io.loadmat('./ЛПП мышей/Без разрушения исходники/100/13_04_2022 4 tr25 healthy 100.mat')

# %%
fig = plt.figure(figsize=(10, 9))
    
ax_1 = fig.add_subplot(3, 1, 1)
ax_2 = fig.add_subplot(3, 1, 2)
ax_3 = fig.add_subplot(3, 1, 3)

ax_1.plot(exp5['Trace_1_25_1_1'][:, 1])
ax_2.plot(exp5['Trace_1_25_1_2'][:, 1])
ax_3.plot(exp5['Trace_1_25_1_3'][:, 1])

plt.show()

# %%
fig = plt.figure(figsize=(10, 9))
    
ax_1 = fig.add_subplot(3, 1, 1)
ax_2 = fig.add_subplot(3, 1, 2)
ax_3 = fig.add_subplot(3, 1, 3)

ax_1.plot((exp5['Trace_1_25_1_2'][:, 1] - exp5['Trace_1_25_1_2'][:, 1].mean()) / exp5['Trace_1_25_1_2'][:, 1].std())
ax_2.plot((exp3['Trace_1_11_1_2'][:, 1] - exp3['Trace_1_11_1_2'][:, 1].mean()) / exp3['Trace_1_11_1_2'][:, 1].std())
ax_3.plot((ca3['Trace_1_9_1_2'][:, 1] - ca3['Trace_1_9_1_2'][:, 1].mean()) / ca3['Trace_1_9_1_2'][:, 1].std())

plt.show()

#plt.plot((exp5['Trace_1_25_1_2'][:, 1] - exp5['Trace_1_25_1_2'][:, 1].mean()) / exp5['Trace_1_25_1_2'][:, 1].std())
