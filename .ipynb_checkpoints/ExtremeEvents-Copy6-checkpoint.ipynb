# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from mpl_toolkits.mplot3d import Axes3D

# %%
from scipy.integrate import solve_ivp

# %%
a = -0.025794
c = 0.02
b1 = 0.0135
b2 = 0.0065
k = 0.129
sigma = 1
alpha = 0.35
eps = 1
beta = 10e-8
q=1.6

# %%
def FHN(self, X):
        x1, y1, x2, y2 = X
        return [x1*(a-x1)*(x1-1) - y1 + k*(x2-x1),
                b1*x1 - c*y1,
                x2*(a-x2)*(x2-1) - y2 + k*(x1-x2),
                b2*x2 - c*y2
               ]

# %%
def jac(t, X):
    x1, y1, x2, y2 = X
    jacobian = np.zeros((4, 4))
    jacobian[0][0] = -3*x1**2 + 2*a*x1 + 2*x1 - k
    jacobian[0][1] = -1
    jacobian[0][2] = k
    jacobian[1][0] = b1
    jacobian[1][1] = -c
    jacobian[2][0] = k
    jacobian[2][2] = -3*x2**2 + 2*a*x2 + 2*x2 - k
    jacobian[2][3] = -1
    jacobian[1][2] = b2
    jacobian[1][3] = -c
    return jacobian

# %%
sol = solve_ivp(FHN, [0, 25000], [-0.123, 0.1, -0.1, -0.1], 
                t_eval=np.array(range(0, 25000, 2)), rtol = 1e-11, atol = 1e-11, dense_output=True)

# %%
train = sol.y[0][100:10000]
test = sol.y[0][10000:] 
#test = sol2.y[0]

# %%
mean = train.mean()
std = train.std()
#sigmastest = np.abs(test - mean)
train_norm = (train - mean)/std
test_norm = (test - mean)/std

# %%
W_in = np.random.uniform(-sigma, sigma, (1000, 1))

# %%
from skimage.io import imshow

# %%
def erdos_renyi(n=1000, p=0.6):
    A = np.zeros((n, n))
    for i in range(n):
        for j in range(i, n):
            if np.random.uniform(0, 1) > p:
                a = np.random.uniform(-1, 1)
                A[i][j] = a
                A[j][i] = a
                
        A[i][i] = 0
            
    return A

# %%
A = erdos_renyi()
imshow(A)

# %%
A = A*(1.6/np.linalg.eig(A)[0].max())

# %%
np.linalg.eig(A)[0].max()
# Out:
# 1.6000000000000036

# %%
def reservoir(U):
    r = np.random.uniform(1, -1, (1000, 1))
    R = np.zeros((1000, len(U)))
    R[:, 0] = r[:, 0]
    for i in range(1, len(U)):
        r = (1-alpha)*r + np.tanh(A@r + W_in*U[i] + eps) #U[i] is a number
        R[:, i] = r[:, 0]
    return R

# %%
#R = reservoir(train)
R = reservoir(train_norm)

# %%
from sklearn.linear_model import Ridge
reg = Ridge(alpha=beta)
#reg.fit(R.T, train)
reg.fit(R.T[1000:], train_norm[1000:])
# Out:
# Ridge(alpha=1e-07)

# %%
def reservoir_step(r, v):
    return (1-alpha)*r + np.tanh(A@r + W_in*v + eps)

# %%
r = np.expand_dims(R[:, -1], axis=1)
def predict(r, v):
    r = reservoir_step(r, v)
    v_new = reg.predict(r.reshape((1, 1000)))
    return r, v_new

# %%
from IPython.display import clear_output

# %%
# all_rms = []
# for M in [10, 20, 25, 30]:
#     v = test[0]
#     predicted = []
#     rms = []
#     r = np.expand_dims(R[:, -1], axis=1)
#     for i in range(len(test)):
#         if i%M == 0 and i != 0:
#             rms.append((v-test[i])**2)
#             v = test[i]        
#         r, v = predict(r, v)
#         predicted.append(v)
#     all_rms.append(np.mean(rms)**0.5)

# %%
#all_rms

# %%
#plt.plot([10, 20, 25, 30], all_rms)

# %%
#np.mean(rms)**0.5

# %%
v = test[0]
predicted = []
rms = []
r = np.expand_dims(R[:, -1], axis=1)
#r = reservoir_step(r, train[-1])
r = reservoir_step(r, train_norm[-1])
for i in range(len(test)):
    if 980 < i < 1100:
        v = test_norm[i] 
        predicted.append(mean + v*std)
        r, v = predict(r, v) 
    else:
        if i %10 == 0 and (i < 950 or i >=1100) and i <= 1930:
            v = test_norm[i] 
            predicted.append(mean + v*std)
            r, v = predict(r, v) 
        else:
        #if mean + v*sigmastest[i] < -800.2:
            
            r, v = predict(r, v)
                    #print(i%10, i, v, sigmastr[i])
            predicted.append(mean + v[0]*std)

# %%
predicted = []
predicted_ee_all = []
M = 20
r = np.expand_dims(R[:, -1], axis=1)
#r = reservoir_step(r, train[-1])
r = reservoir_step(r, train_norm[-1])
for i in range(len(test)):
    r_loop = r
    flag_ee = 0
    v = test_norm[i] 
    predicted_ee = []
    for m in range(M): 
        r_loop, v = predict(r_loop, v)
        predicted_ee.append(((mean + v[0]*std), i))
        if mean + v[0]*std > 0.2:
            flag_ee = 1
        if m == M - 1 and flag_ee == 1:
            predicted_ee_all.append(predicted_ee)
    v = test_norm[i] 
    r = reservoir_step(r, v)
    predicted.append(mean + v*std)

# %%
predicted_ee_all
# Out:
# [[(0.10249183482969487, 29),
#   (0.10281913666788638, 29),
#   (0.10325452933364047, 29),
#   (0.10387483330273285, 29),
#   (0.10474836992778344, 29),
#   (0.10593334303861568, 29),
#   (0.10747814747779465, 29),
#   (0.10942323984030296, 29),
#   (0.11180442420009054, 29),
#   (0.11465760722014214, 29),
#   (0.11802546333027994, 29),
#   (0.12196720727859035, 29),
#   (0.126574042524904, 29),
#   (0.13199521835207126, 29),
#   (0.13848367034251807, 29),
#   (0.1464773847957848, 29),
#   (0.15674627292706358, 29),
#   (0.17066220964142345, 29),
#   (0.19070767610120817, 29),
#   (0.2214412199313189, 29)],
#  [(0.10333225964954723, 30),
#   (0.10383759478184852, 30),
#   (0.1045327557878387, 30),
#   (0.10548585849742681, 30),
#   (0.10675670710865165, 30),
#   (0.10839640389246828, 30),
#   (0.11044910466565896, 30),
#   (0.11295546806225547, 30),
#   (0.11595779616231362, 30),
#   (0.11950739816767131, 30),
#   (0.1236756327765844, 30),
#   (0.12857172511067574, 30),
#   (0.1343732973240529, 30),
#   (0.14138048905739578, 30),
#   (0.15011347958279056, 30),
#   (0.16149055986349728, 30),
#   (0.17715956393636664, 30),
#   (0.20012776714639693, 30),
#   (0.23594528120323935, 30),
#   (0.294541700509813, 30)],
#  [(0.10501361819854453, 31),
#   (0.10587280067379198, 31),
#   (0.10700215151549312, 31),
#   (0.10846164075675888, 31),
#   (0.11030695174432495, 31),
#   (0.11258979025322566, 31),
#   (0.11536129263433291, 31),
#   (0.11867792375886795, 31),
#   (0.12261046397332208, 31),
#   (0.12725813107463135, 31),
#   (0.1327722402488154, 31),
#   (0.139397894184633, 31),
#   (0.14754949771470133, 31),
#   (0.1579496029330848, 31),
#   (0.17188798411476053, 31),
#   (0.19171410423206353, 31),
#   (0.22177914512815386, 31),
#   (0.2700926478263054, 31),
#   (0.349982173351622, 31),
#   (0.4740804260858294, 31)],
#  [(0.10841677786029284, 32),
#   (0.10991084353666958, 32),
#   (0.11176491917261748, 32),
#   (0.11403705293005437, 32),
#   (0.11679197212631824, 32),
#   (0.12010202796791472, 32),
#   (0.12405419730544356, 32),
#   (0.1287630119123534, 32),
#   (0.1343927898343248, 32),
#   (0.1411971301853519, 32),
#   (0.14959143517746282, 32),
#   (0.1602887563842029, 32),
#   (0.17455801558696774, 32),
#   (0.19472232899323413, 32),
#   (0.22512386984284083, 32),
#   (0.27384714512602026, 32),
#   (0.3545982854969585, 32),
#   (0.4799681191501208, 32),
#   (0.5831369444390005, 32),
#   (0.6783539333945436, 32)],
#  [(0.11499329835996298, 33),
#   (0.11760302507716157, 33),
#   (0.1207019067220175, 33),
#   (0.12436610241039758, 33),
#   (0.1287056966788503, 33),
#   (0.13387075552478644, 33),
#   (0.1400744258033271, 33),
#   (0.14763911326443008, 33),
#   (0.15708469870491537, 33),
#   (0.16929880473398376, 33),
#   (0.18587039405008243, 33),
#   (0.20975179159073867, 33),
#   (0.24655399757049964, 33),
#   (0.30672032840902735, 33),
#   (0.40680738931957955, 33),
#   (0.5364094524588862, 33),
#   (0.621283340184675, 33),
#   (0.7723940855813152, 33),
#   (0.9389159044492047, 33),
#   (0.9133088385085488, 33)],
#  [(0.12727889119842134, 34),
#   (0.13189579963816397, 34),
#   (0.13725120944661587, 34),
#   (0.1435046960347641, 34),
#   (0.1509359417120246, 34),
#   (0.1599972203944401, 34),
#   (0.17144382462518107, 34),
#   (0.1866027970691837, 34),
#   (0.20792051757669194, 34),
#   (0.2400774627347208, 34),
#   (0.2920864601841702, 34),
#   (0.37983639444373685, 34),
#   (0.508610598711928, 34),
#   (0.5986067297209218, 34),
#   (0.725547993207426, 34),
#   (0.9223518942465578, 34),
#   (0.9521125213958302, 34),
#   (0.849624451701812, 34),
#   (0.8049821154586349, 34),
#   (0.7380451194727264, 34)],
#  [(0.14998391457407262, 35),
#   (0.15845062183896264, 35),
#   (0.16829035567402853, 35),
#   (0.18006054343490188, 35),
#   (0.1949051961023544, 35),
#   (0.2150494061000808, 35),
#   (0.24486669658572305, 35),
#   (0.2929534964471312, 35),
#   (0.37492015298338605, 35),
#   (0.49781716275263665, 35),
#   (0.5890712400998163, 35),
#   (0.7136591233737053, 35),
#   (0.9279797817100034, 35),
#   (0.9668802884544334, 35),
#   (0.8631114398417113, 35),
#   (0.8121239308906077, 35),
#   (0.7469571811826176, 35),
#   (0.6781889931967651, 35),
#   (0.5899005848244554, 35),
#   (0.48464096052871103, 35)],
#  [(0.19231811342413424, 36),
#   (0.20924316790442046, 36),
#   (0.2301621611523591, 36),
#   (0.2588149758515886, 36),
#   (0.3032929592837809, 36),
#   (0.3784380733128833, 36),
#   (0.4906562600248005, 36),
#   (0.5830058542502452, 36),
#   (0.7134472568978029, 36),
#   (0.9378345881769105, 36),
#   (0.9719907873722303, 36),
#   (0.8717228849998442, 36),
#   (0.815482564853631, 36),
#   (0.7530912553770457, 36),
#   (0.6824431636590629, 36),
#   (0.5923998770733757, 36),
#   (0.4856822554253601, 36),
#   (0.3729145843112339, 36),
#   (0.2986741893703282, 36),
#   (0.34082670763957423, 36)],
#  [(0.27252074939117976, 37),
#   (0.31495191554866464, 37),
#   (0.3796912763698122, 37),
#   (0.4783972140925458, 37),
#   (0.5754036146125444, 37),
#   (0.703524737621071, 37),
#   (0.9230240100588551, 37),
#   (0.980525367826317, 37),
#   (0.8871189671348167, 37),
#   (0.8236784600823259, 37),
#   (0.768213205894818, 37),
#   (0.7020080915771886, 37),
#   (0.6194106130763118, 37),
#   (0.5208364105987906, 37),
#   (0.4131548439257779, 37),
#   (0.32613982546905135, 37),
#   (0.32558903551673535, 37),
#   (0.46356378157042155, 37),
#   (0.612768546204645, 37),
#   (0.7122442894459101, 37)],
#  [(0.42073235192914893, 38),
#   (0.5340389160632864, 38),
#   (0.6267975698254736, 38),
#   (0.795570421148445, 38),
#   (0.9387467525110691, 38),
#   (0.9314515958667827, 38),
#   (0.8517247740758358, 38),
#   (0.8083178332885592, 38),
#   (0.7551770119756782, 38),
#   (0.6975980072655705, 38),
#   (0.6290881054986706, 38),
#   (0.552647541795197, 38),
#   (0.4769758951782888, 38),
#   (0.426468216712494, 38),
#   (0.4384099087475689, 38),
#   (0.5199909660501261, 38),
#   (0.6223942637057939, 38),
#   (0.7300592615303357, 38),
#   (0.8227732213753748, 38),
#   (0.8556992781390506, 38)],
#  [(0.6421966122121253, 39),
#   (0.7552643093885872, 39),
#   (0.8821208400313858, 39),
#   (0.9414981481865301, 39),
#   (0.8724921650768108, 39),
#   (0.833284409650324, 39),
#   (0.7975874120743571, 39),
#   (0.7634367279647208, 39),
#   (0.726288574634173, 39),
#   (0.6813307173041055, 39),
#   (0.62684148707822, 39),
#   (0.5662588269689522, 39),
#   (0.504905218510277, 39),
#   (0.4522085614992769, 39),
#   (0.4150588936546746, 39),
#   (0.3899659407370449, 39),
#   (0.37271449937604084, 39),
#   (0.37046721673549404, 39),
#   (0.40324671293932507, 39),
#   (0.4745981202785153, 39)],
#  [(0.8197412710671086, 40),
#   (0.853999526744058, 40),
#   (0.8618515986324925, 40),
#   (0.8330228014500075, 40),
#   (0.8011868661729893, 40),
#   (0.7678221268567651, 40),
#   (0.7326453914382431, 40),
#   (0.694633606217383, 40),
#   (0.6512607580252104, 40),
#   (0.602192597795287, 40),
#   (0.5506151286147345, 40),
#   (0.5024618955921837, 40),
#   (0.4657135520416758, 40),
#   (0.44157951342729773, 40),
#   (0.41933725613764977, 40),
#   (0.38408133087333873, 40),
#   (0.32850114757324755, 40),
#   (0.2685984744618165, 40),
#   (0.25153712666212585, 40),
#   (0.33724696461615783, 40)],
#  [(0.8725868102671283, 41),
#   (0.8649563325198355, 41),
#   (0.8327028789265256, 41),
#   (0.8009320233287163, 41),
#   (0.7674315499136705, 41),
#   (0.7307194144044249, 41),
#   (0.6885417783807394, 41),
#   (0.6380716400397394, 41),
#   (0.5793905785092216, 41),
#   (0.514848940819348, 41),
#   (0.45089455996427097, 41),
#   (0.39814948816473816, 41),
#   (0.36225236830689717, 41),
#   (0.3485598514796411, 41),
#   (0.3690516804403035, 41),
#   (0.43013015865652326, 41),
#   (0.503866519424403, 41),
#   (0.5622919073689906, 41),
#   (0.6032790748163405, 41),
#   (0.6176773495780439, 41)],
#  [(0.8662965918004534, 42),
#   (0.8322208763740887, 42),
#   (0.8005571112126102, 42),
#   (0.7669875325163151, 42),
#   (0.7303445954855493, 42),
#   (0.6885021107690287, 42),
#   (0.6386775410984518, 42),
#   (0.580941536252791, 42),
#   (0.5178037271573338, 42),
#   (0.45579974302056075, 42),
#   (0.4054949016039857, 42),
#   (0.3719744973389446, 42),
#   (0.35797398953803655, 42),
#   (0.3710558397277718, 42),
#   (0.4172416701737948, 42),
#   (0.47929687658096287, 42),
#   (0.5307071124057702, 42),
#   (0.5657400592800422, 42),
#   (0.578471738192959, 42),
#   (0.5523108723248039, 42)],
#  [(0.8425388572185557, 43),
#   (0.7979611389268214, 43),
#   (0.7654053195972174, 43),
#   (0.728994631482375, 43),
#   (0.6880322752192324, 43),
#   (0.6400315394290844, 43),
#   (0.5851128193351351, 43),
#   (0.5262384571159869, 43),
#   (0.4701716247722168, 43),
#   (0.4269851557923865, 43),
#   (0.39986495306653347, 43),
#   (0.38441233450212076, 43),
#   (0.3768293365529775, 43),
#   (0.37994734392013896, 43),
#   (0.40083831271313486, 43),
#   (0.4371162053973659, 43),
#   (0.47116035544176493, 43),
#   (0.48888170493694977, 43),
#   (0.480912699003066, 43),
#   (0.4274364529656282, 43)],
#  [(0.8125169194842116, 44),
#   (0.7655531297593241, 44),
#   (0.7296432358556132, 44),
#   (0.689742406178834, 44),
#   (0.643465824675109, 44),
#   (0.590906797518716, 44),
#   (0.5352316644210712, 44),
#   (0.48296357547424773, 44),
#   (0.4433314338335783, 44),
#   (0.4181761356577189, 44),
#   (0.39912779961537453, 44),
#   (0.37657343614158584, 44),
#   (0.35050771065407177, 44),
#   (0.3386936003560423, 44),
#   (0.3703747308542322, 44),
#   (0.4475673295991881, 44),
#   (0.5128042968206349, 44),
#   (0.5548872883402188, 44),
#   (0.5882430610360444, 44),
#   (0.6136326113200268, 44)],
#  [(0.7785743487181384, 45),
#   (0.7347325279339152, 45),
#   (0.6968482595049365, 45),
#   (0.6539062739264343, 45),
#   (0.6051259660918663, 45),
#   (0.5534246782570095, 45),
#   (0.504039438009189, 45),
#   (0.46406713789278964, 45),
#   (0.4341484828475403, 45),
#   (0.4032406871579092, 45),
#   (0.35705727948733207, 45),
#   (0.2929215928599128, 45),
#   (0.23746181841032288, 45),
#   (0.24667633331516242, 45),
#   (0.37710382862982395, 45),
#   (0.5871227141232034, 45),
#   (0.6621491244758967, 45),
#   (0.7611175929711632, 45),
#   (0.830751967014625, 45),
#   (0.8286448810667629, 45)],
#  [(0.7404347003249426, 46),
#   (0.7026697936294, 46),
#   (0.6663989622607108, 46),
#   (0.6261057571555693, 46),
#   (0.5836608047527319, 46),
#   (0.5428983081047386, 46),
#   (0.5077622790702375, 46),
#   (0.47761560877902287, 46),
#   (0.44117015282297534, 46),
#   (0.37617592387269055, 46),
#   (0.2533622384082447, 46),
#   (0.046114264994420354, 46),
#   (-0.09220795429475792, 46),
#   (-0.004566255767686274, 46),
#   (0.2780892186790688, 46),
#   (0.7114941091878965, 46),
#   (0.8746265709494633, 46),
#   (1.145997149512333, 46),
#   (1.3076877121738812, 46),
#   (1.3681742690063585, 46)],
#  [(0.6966595366500429, 47),
#   (0.665508900709043, 47),
#   (0.6373989978442743, 47),
#   (0.6097933721597918, 47),
#   (0.5844938426586616, 47),
#   (0.5628925431954953, 47),
#   (0.5434579181933178, 47),
#   (0.5194375653452785, 47),
#   (0.4765227221155591, 47),
#   (0.384438128240011, 47),
#   (0.17564956732725986, 47),
#   (-0.2891189758982609, 47),
#   (-0.7522611493561729, 47),
#   (-0.5927467614846305, 47),
#   (0.10190871073624488, 47),
#   (0.9533401269777615, 47),
#   (2.3682860471889398, 47),
#   (3.3171498950822915, 47),
#   (3.9538240328885483, 47),
#   (4.462598991761374, 47)],
#  [(0.6443386833114141, 48),
#   (0.6220104598217502, 48),
#   (0.611288582433879, 48),
#   (0.6082065205304125, 48),
#   (0.6089014038828887, 48),
#   (0.6087311089202262, 48),
#   (0.6039357631793277, 48),
#   (0.5906442823526309, 48),
#   (0.5611984584484794, 48),
#   (0.4960616983826258, 48),
#   (0.3402567725992731, 48),
#   (-0.07933967039440161, 48),
#   (-0.901881643387865, 48),
#   (-1.103143282447907, 48),
#   (-0.5114200636159192, 48),
#   (0.3535234925235107, 48),
#   (1.443672593472001, 48),
#   (2.328948730316235, 48),
#   (3.0623177915820046, 48),
#   (3.599386519406778, 48)],
#  [(0.5777016615405268, 49),
#   (0.5697301338586266, 49),
#   (0.5876772626189178, 49),
#   (0.6207584494470482, 49),
#   (0.6537994103576653, 49),
#   (0.676253868215487, 49),
#   (0.6846501609420362, 49),
#   (0.6783119201460444, 49),
#   (0.6571780420258334, 49),
#   (0.6186799106421573, 49),
#   (0.5505457389819082, 49),
#   (0.40684366526388854, 49),
#   (0.017253690960311194, 49),
#   (-1.0137420509716586, 49),
#   (-1.2547567965138324, 49),
#   (-1.0643909431570864, 49),
#   (-0.8220043835469704, 49),
#   (-0.29452437824580824, 49),
#   (0.7790746689204618, 49),
#   (2.092759697907469, 49)],
#  [(0.48482111326065486, 50),
#   (0.5069535446689727, 50),
#   (0.5694552216561576, 50),
#   (0.6442790140597255, 50),
#   (0.7147723660146448, 50),
#   (0.7664996154578736, 50),
#   (0.7776947509660698, 50),
#   (0.7565722358398815, 50),
#   (0.7216719940848815, 50),
#   (0.6796963809429194, 50),
#   (0.6319554751061479, 50),
#   (0.5696323219314745, 50),
#   (0.45696179373566986, 50),
#   (0.170675878380812, 50),
#   (-0.8598128458228018, 50),
#   (-1.7228512965541467, 50),
#   (-1.895673585045315, 50),
#   (-2.1404866400466123, 50),
#   (0.10831407193814198, 565),
#   (0.11011809807320215, 565),
#   (0.11234826184367774, 565),
#   (0.11504704856282376, 565),
#   (0.1182624104639789, 565),
#   (0.12205733854039771, 565),
#   (0.12652503971688453, 565),
#   (0.13181443753207048, 565),
#   (0.1381746455023234, 565),
#   (0.14603404695811134, 565),
#   (0.15614292641404368, 565),
#   (0.16983573952806713, 565),
#   (0.1895252762208546, 565),
#   (0.21964146091078673, 565),
#   (0.2682552725444, 565),
#   (0.3485322712810488, 565)],
#  [(0.1071475200689987, 566),
#   (0.1082602628136069, 566),
#   (0.10967467752362567, 566),
#   (0.11144764954426958, 566),
#   (0.11363743625396339, 566),
#   (0.11630345008069973, 566),
#   (0.1195108709522383, 566),
#   (0.12333928601441436, 566),
#   (0.1278969094902476, 566),
#   (0.13334461762876135, 566),
#   (0.13993828668444402, 566),
#   (0.14810543444611687, 566),
#   (0.15858634013304113, 566),
#   (0.17269822684847247, 566),
#   (0.1928392368542265, 566),
#   (0.22345351098242142, 566),
#   (0.2727159904393551, 566),
#   (0.3541657477468593, 566),
#   (0.47988365079643364, 566),
#   (0.5848606357154565, 566)],
#  [(0.11246426073877253, 567),
#   (0.11449314997401858, 567),
#   (0.11693395489630301, 567),
#   (0.11985193649744118, 567),
#   (0.12333356609184716, 567),
#   (0.1274887523240475, 567),
#   (0.13246448616025866, 567),
#   (0.13847171873698563, 567),
#   (0.14583480818966896, 567),
#   (0.15508368464028968, 567),
#   (0.1671287747334052, 567),
#   (0.1835986780396164, 567),
#   (0.2075011157583809, 567),
#   (0.24449488807288758, 567),
#   (0.3049497259758395, 567),
#   (0.40493818138373816, 567),
#   (0.5357847636455629, 567),
#   (0.6224042770892056, 567),
#   (0.7712421469462714, 567),
#   (0.9321852201253019, 567)],
#  [(0.1224389682355347, 568),
#   (0.126096973515397, 568),
#   (0.13035944064047172, 568),
#   (0.13534407609550012, 568),
#   (0.1412466058009295, 568),
#   (0.14836520622228394, 568),
#   (0.15716786964900734, 568),
#   (0.16842884875308406, 568),
#   (0.18349891496035772, 568),
#   (0.20484734626610812, 568),
#   (0.23715055848351355, 568),
#   (0.2893013966621019, 568),
#   (0.37676231914115876, 568),
#   (0.506391722526945, 568),
#   (0.5989819757084421, 568),
#   (0.722983592968736, 568),
#   (0.9149422245344287, 568),
#   (0.9516451432981425, 568),
#   (0.8479317748625681, 568),
#   (0.8042419043856294, 568)],
#  [(0.14086782360702768, 569),
#   (0.14757408851841153, 569),
#   (0.15533620467200698, 569),
#   (0.16450490187613473, 569),
#   (0.17575824057828318, 569),
#   (0.19032644787506572, 569),
#   (0.21049369555987882, 569),
#   (0.24063909952796272, 569),
#   (0.2892563403260307, 569),
#   (0.3717365817385095, 569),
#   (0.4967983226809329, 569),
#   (0.5902861770495639, 569),
#   (0.7122891092407755, 569),
#   (0.9217620153072212, 569),
#   (0.9656732643786398, 569),
#   (0.8607635199631987, 569),
#   (0.81122930198778, 569),
#   (0.7459358440775066, 569),
#   (0.6785010103286512, 569),
#   (0.5918780638348319, 569)],
#  [(0.17507642146858649, 570),
#   (0.18813414987214835, 570),
#   (0.20378102193645042, 570),
#   (0.22389389572662635, 570),
#   (0.2525695824872494, 570),
#   (0.2980981851833881, 570),
#   (0.3755478485094292, 570),
#   (0.4919762962369101, 570),
#   (0.5850233163907068, 570),
#   (0.7138019122201635, 570),
#   (0.9358440756226203, 570),
#   (0.9695540987154324, 570),
#   (0.8683297051643214, 570),
#   (0.8140690847801874, 570),
#   (0.7507061060000673, 570),
#   (0.6805634674144591, 570),
#   (0.5908056604344586, 570),
#   (0.4838985603274338, 570),
#   (0.3708064408702901, 570),
#   (0.29688740545061015, 570)],
#  [(0.2396700667330776, 571),
#   (0.2695555745262088, 571),
#   (0.3117683271102163, 571),
#   (0.3797922520605216, 571),
#   (0.4830767479093117, 571),
#   (0.5792102510476415, 571),
#   (0.7121165209493625, 571),
#   (0.9349685999549353, 571),
#   (0.9748480895707432, 571),
#   (0.8782739574105682, 571),
#   (0.8187810040065165, 571),
#   (0.7601846673877499, 571),
#   (0.6914419582923433, 571),
#   (0.6046717924365281, 571),
#   (0.5016082169678284, 571),
#   (0.3907872996456073, 571),
#   (0.30944353107434946, 571),
#   (0.3303116314667639, 571),
#   (0.48543686696169785, 571),
#   (0.6180747103280541, 571)],
#  [(0.36142276810910945, 572),
#   (0.4530261810003183, 572),
#   (0.5560158604753361, 572),
#   (0.6610895547362151, 572),
#   (0.8616669039678472, 572),
#   (0.9787452880393969, 572),
#   (0.9122606670825507, 572),
#   (0.8389207932071707, 572),
#   (0.7916998582863681, 572),
#   (0.733811102276929, 572),
#   (0.6659203631286718, 572),
#   (0.5840670079966692, 572),
#   (0.4919669738312011, 572),
#   (0.40212617141610035, 572),
#   (0.3550649096586072, 572),
#   (0.4058274107128551, 572),
#   (0.5479732409541381, 572),
#   (0.6697711695214085, 572),
#   (0.7826297376876757, 572),
#   (0.8767374975528376, 572)],
#  [(0.5645063876340862, 573),
#   (0.6826040876269451, 573),
#   (0.8505358881365368, 573),
#   (0.9662712237062863, 573),
#   (0.9190480103426708, 573),
#   (0.8541694460300175, 573),
#   (0.8163100807130753, 573),
#   (0.776110138538628, 573),
#   (0.7329295542876606, 573),
#   (0.6822551558326584, 573),
#   (0.6233928061963829, 573),
#   (0.5579894627568807, 573),
#   (0.49060226928252526, 573),
#   (0.433643564811837, 573),
#   (0.4018369201183156, 573),
#   (0.4038068454542998, 573),
#   (0.44215408864483746, 573),
#   (0.5013893146251602, 573),
#   (0.554192013437782, 573),
#   (0.5846012614974695, 573)],
#  [(0.7757231305690516, 574),
#   (0.8203907386730082, 574),
#   (0.8546384920066562, 574),
#   (0.8491158201716823, 574),
#   (0.8147314945987467, 574),
#   (0.7829060009538682, 574),
#   (0.7493155843888853, 574),
#   (0.715516236212469, 574),
#   (0.6798328856798073, 574),
#   (0.6402526117935735, 574),
#   (0.59816909318089, 574),
#   (0.557993446896372, 574),
#   (0.5253017326150301, 574),
#   (0.503284818738811, 574),
#   (0.486255824957009, 574),
#   (0.45916203938515054, 574),
#   (0.40026380728083255, 574),
#   (0.2806971778543255, 574),
#   (0.07061504494443162, 574),
#   (-0.11059487657967132, 574)],
#  [(0.8653759278197294, 575),
#   (0.8714877728678476, 575),
#   (0.8428541847577949, 575),
#   (0.8107170681468036, 575),
#   (0.777889745393591, 575),
#   (0.7422931414342769, 575),
#   (0.7024260386247525, 575),
#   (0.6553816389657757, 575),
#   (0.6001276557629567, 575),
#   (0.5386354680980154, 575),
#   (0.4759772450228868, 575),
#   (0.42288698332177505, 575),
#   (0.38755612155301195, 575),
#   (0.37214885583687435, 575),
#   (0.3788364431467804, 575),
#   (0.40884616529414813, 575),
#   (0.45251071630745626, 575),
#   (0.49070026603160505, 575),
#   (0.5123136381281131, 575),
#   (0.508811109940957, 575)],
#  [(0.8711796669949958, 576),
#   (0.8430733301129368, 576),
#   (0.8109559006161928, 576),
#   (0.7781604128467536, 576),
#   (0.7425289665369247, 576),
#   (0.7024281018421282, 576),
#   (0.654882254172701, 576),
#   (0.5988831960818941, 576),
#   (0.5363117720611837, 576),
#   (0.47213414127656944, 576),
#   (0.41717005572480886, 576),
#   (0.37989596804082787, 576),
#   (0.36414170420887815, 576),
#   (0.37532528817221883, 576),
#   (0.416199220240783, 576),
#   (0.4713362352904827, 576),
#   (0.5169744564004417, 576),
#   (0.5448020429701227, 576),
#   (0.5471412035733935, 576),
#   (0.5054213306349504, 576)],
#  [(0.8508023172563353, 577),
#   (0.8086844407992212, 577),
#   (0.7768774293333441, 577),
#   (0.7412504136137457, 577),
#   (0.7016586310134535, 577),
#   (0.6554129974514574, 577),
#   (0.6015243465861668, 577),
#   (0.5421560985886864, 577),
#   (0.4826758409275064, 577),
#   (0.4336889914330661, 577),
#   (0.402717151370266, 577),
#   (0.3887811190317595, 577),
#   (0.38788103915498034, 577),
#   (0.39726251556545283, 577),
#   (0.4150852828165547, 577),
#   (0.43602815758568114, 577),
#   (0.45040732431135677, 577),
#   (0.4475021436367139, 577),
#   (0.4141474596978924, 577),
#   (0.33553289810326586, 577)],
#  [(0.8223268699457335, 578),
#   (0.7754799777167266, 578),
#   (0.7405760692104204, 578),
#   (0.7017060054456977, 578),
#   (0.6568749667495393, 578),
#   (0.6051847909798622, 578),
#   (0.5490431205623291, 578),
#   (0.4940346292304899, 578),
#   (0.4501929437615723, 578),
#   (0.42381580225357773, 578),
#   (0.4100110689579051, 578),
#   (0.3980480379645026, 578),
#   (0.3804636281769211, 578),
#   (0.36085165327701363, 578),
#   (0.35679215850497836, 578),
#   (0.38825302917767024, 578),
#   (0.44504888849215934, 578),
#   (0.4866163805342524, 578),
#   (0.5017101461187301, 578),
#   (0.48515162090412106, 578)],
#  [(0.7896379896729934, 579),
#   (0.7440812737851993, 579),
#   (0.7062364062171352, 579),
#   (0.6635246669685113, 579),
#   (0.614401010667756, 579),
#   (0.5611476936120918, 579),
#   (0.5087769631575533, 579),
#   (0.4657625483667883, 579),
#   (0.4372627900658784, 579),
#   (0.4166359274425276, 579),
#   (0.39062562225264585, 579),
#   (0.3507632649783002, 579),
#   (0.3065576511447074, 579),
#   (0.29428173544136277, 579),
#   (0.2587735006849726, 1483),
#   (0.3201433823286175, 1483),
#   (0.42204221806106546, 1483),
#   (0.5442737709542086, 1483),
#   (0.6301513057261938, 1483),
#   (0.8059008532387114, 1483),
#   (0.9712496952525643, 1483),
#   (0.9037402992972698, 1483),
#   (0.8315558732650921, 1483),
#   (0.7788055854812571, 1483),
#   (0.7144485823512524, 1483),
#   (0.6390175920181175, 1483),
#   (0.5440979248919766, 1483)],
#  [(0.179279998752515, 1484),
#   (0.19397084885420418, 1484),
#   (0.2118965123006732, 1484),
#   (0.23569807311226532, 1484),
#   (0.2708951982581878, 1484),
#   (0.32801043741825486, 1484),
#   (0.4229416541434862, 1484),
#   (0.5375315519623192, 1484),
#   (0.625246823826151, 1484),
#   (0.8124112123147711, 1484),
#   (0.9862876073321317, 1484),
#   (0.9147800325810185, 1484),
#   (0.836345598324119, 1484),
#   (0.7853795894440511, 1484),
#   (0.7191372012237593, 1484),
#   (0.6411221429970221, 1484),
#   (0.5428836603662222, 1484),
#   (0.43021546664591825, 1484),
#   (0.3266128818767421, 1484),
#   (0.29489254837181156, 1484)],
#  [(0.24959461431631494, 1485),
#   (0.28367084081906796, 1485),
#   (0.3329415859661584, 1485),
#   (0.41204711366071134, 1485),
#   (0.518850960663305, 1485),
#   (0.6095894363119755, 1485),
#   (0.7868803333269574, 1485),
#   (0.9698867834758459, 1485),
#   (0.9329427828680543, 1485),
#   (0.8473480988951586, 1485),
#   (0.7995111928572501, 1485),
#   (0.7361432658328384, 1485),
#   (0.6636277031307356, 1485),
#   (0.5722123603890076, 1485),
#   (0.46731999184923806, 1485),
#   (0.36497215279256306, 1485),
#   (0.3151087203915928, 1485),
#   (0.38963894402442967, 1485),
#   (0.5568654635169032, 1485),
#   (0.6526620269123313, 1485)],
#  [(0.3788254015900745, 1486),
#   (0.47912240258160227, 1486),
#   (0.5771823270360116, 1486),
#   (0.6998516239398284, 1486),
#   (0.8940838743151001, 1486),
#   (0.9690560109755545, 1486),
#   (0.8855941714380005, 1486),
#   (0.8255380969482509, 1486),
#   (0.7764051695042323, 1486),
#   (0.719510819610335, 1486),
#   (0.6520129034117822, 1486),
#   (0.572840251537635, 1486),
#   (0.48794864281962663, 1486),
#   (0.41564908707338916, 1486),
#   (0.39729908790820295, 1486),
#   (0.4683544543750616, 1486),
#   (0.5877325550908121, 1486),
#   (0.697419198432691, 1486),
#   (0.8042053173601121, 1486),
#   (0.8702759898958391, 1486)],
#  [(0.58551133968745, 1487),
#   (0.7079969145154222, 1487),
#   (0.8676127478031748, 1487),
#   (0.9642519776297513, 1487),
#   (0.9024703618186929, 1487),
#   (0.845801468053797, 1487),
#   (0.809308674214606, 1487),
#   (0.771045281244936, 1487),
#   (0.7301806594528624, 1487),
#   (0.6824120596935684, 1487),
#   (0.6266121469423805, 1487),
#   (0.5651215524223994, 1487),
#   (0.5033767916144314, 1487),
#   (0.4531964368866529, 1487),
#   (0.42663208695051785, 1487),
#   (0.4257666277861855, 1487),
#   (0.4438731143811494, 1487),
#   (0.4667760343474792, 1487),
#   (0.478335115918767, 1487),
#   (0.46398302397867625, 1487)],
#  [(0.7853006571286832, 1488),
#   (0.8232608470999098, 1488),
#   (0.849132438340328, 1488),
#   (0.840232228653771, 1488),
#   (0.8071388544362509, 1488),
#   (0.7747869437574392, 1488),
#   (0.7410554433693963, 1488),
#   (0.7071193473665985, 1488),
#   (0.6721165316238011, 1488),
#   (0.63514474267866, 1488),
#   (0.5983682153730804, 1488),
#   (0.566429394903407, 1488),
#   (0.544045097972599, 1488),
#   (0.531897411191332, 1488),
#   (0.5229567002065343, 1488),
#   (0.5044468580385353, 1488),
#   (0.45810156804711005, 1488),
#   (0.34997036403833304, 1488),
#   (0.11813379476089242, 1488),
#   (-0.2766777469578395, 1488)],
#  [(0.8636129025238136, 1489),
#   (0.8660836128696362, 1489),
#   (0.8366382141385247, 1489),
#   (0.8041576130267561, 1489),
#   (0.7708818850723806, 1489),
#   (0.7350778313870339, 1489),
#   (0.6955793739096524, 1489),
#   (0.6500709277362282, 1489),
#   (0.5981613681675827, 1489),
#   (0.5428959030243627, 1489),
#   (0.4910255518447462, 1489),
#   (0.4533106951371293, 1489),
#   (0.43457943247539826, 1489),
#   (0.42706814239922536, 1489),
#   (0.41626371143183927, 1489),
#   (0.3901124395352018, 1489),
#   (0.3469604124310092, 1489),
#   (0.3061608591351333, 1489),
#   (0.3092728216583951, 1489),
#   (0.3940158492204191, 1489)],
#  [(0.8659557000408272, 1490),
#   (0.8367643639562845, 1490),
#   (0.8042780060860751, 1490),
#   (0.7710140673027641, 1490),
#   (0.7351937846937147, 1490),
#   (0.6955960420482095, 1490),
#   (0.6498638389880672, 1490),
#   (0.5976022548735116, 1490),
#   (0.5418220262810803, 1490),
#   (0.4892584389768825, 1490),
#   (0.45078403731163236, 1490),
#   (0.4314335112529021, 1490),
#   (0.4239230204566072, 1490),
#   (0.414393040450263, 1490),
#   (0.39143584955907695, 1490),
#   (0.35378737007514505, 1490),
#   (0.31930456292638315, 1490),
#   (0.3254432182537714, 1490),
#   (0.40184515976446794, 1490),
#   (0.49772833837473873, 1490)],
#  [(0.8447268964712206, 1491),
#   (0.8019466579032444, 1491),
#   (0.769687384297394, 1491),
#   (0.7339268570772187, 1491),
#   (0.6948266404228599, 1491),
#   (0.6504061094785833, 1491),
#   (0.6003934499070611, 1491),
#   (0.5480601948077543, 1491),
#   (0.5003111519476954, 1491),
#   (0.4672614145622331, 1491),
#   (0.4524356986356349, 1491),
#   (0.44571057475831066, 1491),
# ...
#   (0.4393154760840812, 2393),
#   (0.3650441292795692, 2393),
#   (0.36754448975041926, 2393),
#   (0.48384576319163686, 2393),
#   (0.6190544132027439, 2393),
#   (0.7277825161936889, 2393),
#   (0.8410455413537445, 2393)],
#  [(0.5079809102349251, 2394),
#   (0.6111656415042583, 2394),
#   (0.7622114464421442, 2394),
#   (0.9129590062807207, 2394),
#   (0.9523934933361824, 2394),
#   (0.8726036727861762, 2394),
#   (0.8261252792774282, 2394),
#   (0.7817250530276386, 2394),
#   (0.7348161119855355, 2394),
#   (0.6816483309166146, 2394),
#   (0.6224494290720063, 2394),
#   (0.5599527724130077, 2394),
#   (0.5013934271674568, 2394),
#   (0.4645480648340182, 2394),
#   (0.4696146293442987, 2394),
#   (0.5172134697311674, 2394),
#   (0.5852195634687796, 2394),
#   (0.6524960975044863, 2394),
#   (0.7062520619182886, 2394),
#   (0.7390780112134432, 2394)],
#  [(0.7321430832582515, 2395),
#   (0.7956713507352394, 2395),
#   (0.8541681048319526, 2395),
#   (0.8741500681004011, 2395),
#   (0.8319960224556762, 2395),
#   (0.801106345875886, 2395),
#   (0.7677385363758218, 2395),
#   (0.7363703338746139, 2395),
#   (0.7044415225836408, 2395),
#   (0.6679843705832309, 2395),
#   (0.6255527386407124, 2395),
#   (0.5808079557524025, 2395),
#   (0.5390913996110289, 2395),
#   (0.5058526410350231, 2395),
#   (0.4810383045908565, 2395),
#   (0.453701517322471, 2395),
#   (0.404261230208308, 2395),
#   (0.3078233489864986, 2395),
#   (0.14147371389398333, 2395),
#   (-0.06608774783007532, 2395)],
#  [(0.8539426198441011, 2396),
#   (0.8712114397080452, 2396),
#   (0.8509688710914409, 2396),
#   (0.8183534312794332, 2396),
#   (0.7862699331192811, 2396),
#   (0.7518343632055805, 2396),
#   (0.7143054350424842, 2396),
#   (0.6710787493951126, 2396),
#   (0.620092185350637, 2396),
#   (0.5628958178425204, 2396),
#   (0.5037443451939166, 2396),
#   (0.45144694548009023, 2396),
#   (0.4144110679669839, 2396),
#   (0.3919387218317259, 2396),
#   (0.3793079366330293, 2396),
#   (0.3759437894377373, 2396),
#   (0.3883933324949475, 2396),
#   (0.42135735276405845, 2396),
#   (0.4626729637058506, 2396),
#   (0.49402168540256586, 2396)],
#  [(0.8730459643023251, 2397),
#   (0.8513392242515909, 2397),
#   (0.8189303993368325, 2397),
#   (0.7868775189332922, 2397),
#   (0.752399553151042, 2397),
#   (0.7142035989493414, 2397),
#   (0.6693413010124108, 2397),
#   (0.6158285932889739, 2397),
#   (0.5551317202491997, 2397),
#   (0.49111522749984554, 2397),
#   (0.4329075576651641, 2397),
#   (0.3895455083930698, 2397),
#   (0.36386548169292204, 2397),
#   (0.3604319936159558, 2397),
#   (0.3884646969528433, 2397),
#   (0.44665181502153745, 2397),
#   (0.507671235103551, 2397),
#   (0.5544980496912877, 2397),
#   (0.5836795248433733, 2397),
#   (0.5842124514081277, 2397)],
#  [(0.8564734801335311, 2398),
#   (0.817328954021832, 2398),
#   (0.7858423655286176, 2398),
#   (0.7512567325902835, 2398),
#   (0.713335022841803, 2398),
#   (0.6694093241221369, 2398),
#   (0.6175271058131593, 2398),
#   (0.5592511160000988, 2398),
#   (0.49882059581037724, 2398),
#   (0.44534075726583483, 2398),
#   (0.40748591688045716, 2398),
#   (0.3855083656651549, 2398),
#   (0.37681729407486014, 2398),
#   (0.38242862513355985, 2398),
#   (0.40614544047333434, 2398),
#   (0.44362815623541785, 2398),
#   (0.47883727182222907, 2398),
#   (0.49970552902060006, 2398),
#   (0.49802981450308875, 2398),
#   (0.4570869471782895, 2398)],
#  [(0.8294738327333583, 2399),
#   (0.7837810906465444, 2399),
#   (0.7499806181720262, 2399),
#   (0.7125743460152675, 2399),
#   (0.6698954599937268, 2399),
#   (0.620169722540524, 2399),
#   (0.5651023027208423, 2399),
#   (0.5093176666482537, 2399),
#   (0.4616421321105112, 2399),
#   (0.4298382706638526, 2399),
#   (0.41111252632298134, 2399),
#   (0.3956047748240863, 2399),
#   (0.37590600177463973, 2399),
#   (0.3560793963875163, 2399),
#   (0.35560556403208876, 2399),
#   (0.395894655331074, 2399),
#   (0.4616521507970661, 2399),
#   (0.5102158924799397, 2399),
#   (0.5394811351426224, 2399),
#   (0.5541536575420624, 2399)],
#  [(0.7977758051157395, 2400),
#   (0.7521129110972522, 2400),
#   (0.7153934022602876, 2400),
#   (0.6743821135721394, 2400),
#   (0.6268666820435027, 2400),
#   (0.5744225078490894, 2400),
#   (0.5215231450624324, 2400),
#   (0.4759864309814984, 2400),
#   (0.44459330607877484, 2400),
#   (0.4232172741266524, 2400),
#   (0.3990341225577487, 2400),
#   (0.36116634082639654, 2400),
#   (0.31369340832588005, 2400),
#   (0.2881339565398582, 2400),
#   (0.3347921302771749, 2400),
#   (0.47308956067407854, 2400),
#   (0.5678691438569687, 2400),
#   (0.6344447262729119, 2400),
#   (0.7085418895674479, 2400),
#   (0.7562789037529687, 2400)],
#  [(0.7622169716505555, 2401),
#   (0.7212522278108802, 2401),
#   (0.6838404904689218, 2401),
#   (0.641459483820483, 2401),
#   (0.5946769504277245, 2401),
#   (0.5473190035413272, 2401),
#   (0.5049498293883142, 2401),
#   (0.4721370421957687, 2401),
#   (0.44402491815333933, 2401),
#   (0.4046850667940753, 2401),
#   (0.33470777369968874, 2401),
#   (0.2259908940257068, 2401),
#   (0.10130629682055567, 2401),
#   (0.09843421789830538, 2401),
#   (0.26958575926604567, 2401),
#   (0.5640050390964695, 2401),
#   (0.6897706106192194, 2401),
#   (0.850283795606983, 2401),
#   (1.000688656010051, 2401),
#   (1.0569297931977681, 2401)],
#  [(0.7220192138765407, 2402),
#   (0.6872792207052291, 2402),
#   (0.6537594813286611, 2402),
#   (0.6179924799025898, 2402),
#   (0.5823878180994109, 2402),
#   (0.5504030290776487, 2402),
#   (0.5239002430285825, 2402),
#   (0.49886656329208645, 2402),
#   (0.4622145877953805, 2402),
#   (0.3889346688152539, 2402),
#   (0.23503244101361664, 2402),
#   (-0.07486014128720545, 2402),
#   (-0.3882051633475543, 2402),
#   (-0.35294681350466683, 2402),
#   (-0.12089825012525121, 2402),
#   (-0.12020562049493913, 2402),
#   (-0.24367307665134944, 2402),
#   (-0.5007219481442433, 2402),
#   (0.04627196689923488, 2402),
#   (0.46170627243306667, 2402)],
#  [(0.6750915105560439, 2403),
#   (0.6473458530258365, 2403),
#   (0.6256637247436461, 2403),
#   (0.6076815772819298, 2403),
#   (0.593632638427124, 2403),
#   (0.5824930144797776, 2403),
#   (0.5710522281406951, 2403),
#   (0.553324079957729, 2403),
#   (0.5182427325630609, 2403),
#   (0.4408941956874071, 2403),
#   (0.255853647303021, 2403),
#   (-0.22908276883542608, 2403),
#   (-0.9047359574351138, 2403),
#   (-0.7257293005259835, 2403),
#   (0.011444627280866607, 2403),
#   (0.4453747648133559, 2403),
#   (1.1753222873860192, 2403),
#   (2.00870427331888, 2403),
#   (2.940267001021998, 2403),
#   (3.4923667930671614, 2403)],
#  [(0.6175521700623414, 2404),
#   (0.6003470993600877, 2404),
#   (0.6008171910141132, 2404),
#   (0.6131233220177966, 2404),
#   (0.6283836757954159, 2404),
#   (0.6388129177744033, 2404),
#   (0.641197913970677, 2404),
#   (0.6341767461758115, 2404),
#   (0.6146128457598744, 2404),
#   (0.5734235621004043, 2404),
#   (0.4845027019165337, 2404),
#   (0.26584163520037163, 2404),
#   (-0.4175484741063397, 2404),
#   (-1.4075148010574123, 2404),
#   (-1.1625115427342183, 2404),
#   (-0.7329245217402369, 2404),
#   (-0.03228301406360261, 2404),
#   (0.7061887739684997, 2404),
#   (1.8600107422948409, 2404),
#   (2.632327389185562, 2404)],
#  [(0.5417670144658474, 2405),
#   (0.5435485793515734, 2405),
#   (0.578755815453424, 2405),
#   (0.6310460658935344, 2405),
#   (0.6812627721254346, 2405),
#   (0.7158824490303382, 2405),
#   (0.727303998094622, 2405),
#   (0.7159476263774361, 2405),
#   (0.6881738350800345, 2405),
#   (0.6478567105843785, 2405),
#   (0.5914746436749958, 2405),
#   (0.49569791076604885, 2405),
#   (0.271953645121229, 2405),
#   (-0.4825804011500555, 2405),
#   (-1.6642741791234439, 2405),
#   (-1.6088697474636693, 2405),
#   (-1.528323447415772, 2405),
#   (-1.5902458015455108, 2405),
#   (-1.752869751356414, 2405),
#   (-1.985213490571417, 2405)],
#  [(0.4310743672551576, 2406),
#   (0.4783155270014112, 2406),
#   (0.5766242925764798, 2406),
#   (0.6747304950865968, 2406),
#   (0.7629257200471848, 2406),
#   (0.8197508623794799, 2406),
#   (0.8140192545696515, 2406),
#   (0.7878192923513854, 2406),
#   (0.7532878303548339, 2406),
#   (0.7136385326812906, 2406),
#   (0.6735906893631712, 2406),
#   (0.6328295151872039, 2406),
#   (0.582117587182676, 2406),
#   (0.49681552720704825, 2406),
#   (0.30290447874664855, 2406),
#   (-0.3268229910182326, 2406),
#   (-1.399772361229888, 2406),
#   (-1.1208349956141521, 2406),
#   (-0.7199925555544612, 2406),
#   (-0.13298402703384543, 2406)],
#  [(0.2525410546519371, 2407),
#   (0.43583418295605614, 2407),
#   (0.6715707847642384, 2407),
#   (0.8108458536013211, 2407),
#   (0.9256207602704417, 2407),
#   (0.9487663664112831, 2407),
#   (0.9387891806998417, 2407),
#   (0.9260580612006435, 2407),
#   (0.8891081478682961, 2407),
#   (0.8256285323412986, 2407),
#   (0.754655306550905, 2407),
#   (0.7113296604818427, 2407),
#   (0.6796260323999591, 2407),
#   (0.6541682495375437, 2407),
#   (0.6266378504180679, 2407),
#   (0.5970919522575124, 2407),
#   (0.5544234881508208, 2407),
#   (0.4971004408931368, 2407),
#   (0.3959387782985006, 2407),
#   (0.18151449192451038, 2407)],
#  [(-0.014790471089784908, 2408),
#   (0.21937994156064125, 2408),
#   (-0.23055090837519546, 2421),
#   (-0.2404540620845341, 2421),
#   (-0.2677871015754296, 2421),
#   (-0.3379996175722719, 2421),
#   (-0.558274419323467, 2421),
#   (-1.1104425028150777, 2421),
#   (0.5906780484472754, 2421),
#   (1.9559810135335192, 2421),
#   (3.2423667137035905, 2421),
#   (3.9099999810547073, 2421),
#   (4.747293609467795, 2421),
#   (5.172744658046454, 2421),
#   (5.25746527775368, 2421),
#   (5.224324979445441, 2421),
#   (5.166584622137919, 2421),
#   (5.109811525523974, 2421),
#   (5.059500309102458, 2421),
#   (5.015741910756152, 2421),
#   (4.977338743627086, 2421)],
#  [(-0.2159500075283255, 2422),
#   (-0.2164935344212699, 2422),
#   (-0.22345389865964949, 2422),
#   (-0.24055581597422013, 2422),
#   (-0.27623557627938394, 2422),
#   (-0.3594768195183187, 2422),
#   (-0.625075659761965, 2422),
#   (-1.05559004020907, 2422),
#   (0.5278008968832201, 2422),
#   (1.7453053381187542, 2422),
#   (3.3402072766795667, 2422),
#   (3.982960927766323, 2422),
#   (4.839266030986118, 2422),
#   (5.292498568411928, 2422),
#   (5.38094071655089, 2422),
#   (5.342498515590047, 2422),
#   (5.277937413450048, 2422),
#   (5.214845612437642, 2422),
#   (5.159237860189261, 2422),
#   (5.111336325232451, 2422)],
#  [(-0.20264328895713102, 2423),
#   (-0.201877358623239, 2423),
#   (-0.20444783363313143, 2423),
#   (-0.20998845510147662, 2423),
#   (-0.21744111707630107, 2423),
#   (-0.22561099174358262, 2423),
#   (-0.23368703080284578, 2423),
#   (-0.24186518522811282, 2423),
#   (-0.25233145137179835, 2423),
#   (-0.27137222756116536, 2423),
#   (-0.3161660292552459, 2423),
#   (-0.4444972260434911, 2423),
#   (-0.8990971308078423, 2423),
#   (0.1933165159009989, 2423),
#   (0.4373202401760711, 2423),
#   (0.6584602498510943, 2423),
#   (0.7237540773070623, 2423),
#   (0.6954802333689581, 2423),
#   (0.769047890183276, 2423),
#   (0.9990539952690843, 2423)]]

# %%
plt.plot(sol.t[10000:][564:],test[564:])

# %%
afavav
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-9a58af4abb1b> in <module>
# ----> 1 afavav
#
# NameError: name 'afavav' is not defined

# %% [markdown]
# Попробовать предсказывать только на 20 шагов вперед, но резервуар обновлять по u

# %%
v = test[0]
predicted = []
rms = []
r = np.expand_dims(R[:, -1], axis=1)
#r = reservoir_step(r, train[-1])
r = reservoir_step(r, train_norm[-1])
for i in range(len(test)):
    if  i <= 940:
        v = test_norm[i] 
        predicted.append(mean + v*std)
        r, v = predict(r, v) 
    else:
        #if mean + v*sigmastest[i] < -800.2:
        r, v = predict(r, v)
                    #print(i%10, i, v, sigmastr[i])
        predicted.append(mean + v[0]*std)

# %%
plt.plot(sol.t[1100:10000], reg.predict(R.T[1000:]))

# %%
plt.plot(sol.t[1100:10000], train_norm[1000:])

# %%
plt.plot(sol.t[10000:],test)
#plt.plot(sol2.t,test)

# %%
test[956]

# %%
plt.plot(sol.t[10000:],predicted[:])
#plt.plot(sol2.t,predicted)

# %%
#plt.plot(sol.t[10000:], predicted)
#plt.plot(sol.t[10000:], test)

# %%
def FHN_correcting(t, X):    
        x1, y1, x2, y2 = X
        #if t == t_global or (-t + (np.array(T_events) - 50) < 1e-4).sum() > 0:
        if t == t_global-40:
            print(t)
            
            return [x1*(a-x1)*(x1-1) - y1 + k*(x2-x1) - 1,
                    b1*x1 - c*y1,
                    x2*(a-x2)*(x2-1) - y2 + k*(x1-x2),
                    b2*x2 - c*y2
                   ]
        
        return [x1*(a-x1)*(x1-1) - y1 + k*(x2-x1),
                    b1*x1 - c*y1,
                    x2*(a-x2)*(x2-1) - y2 + k*(x1-x2),
                    b2*x2 - c*y2
                   ]

# %%
t_global = sol.t[10000:][950]

# %%
smth = solve_ivp(FHN_correcting, [sol.t[10000:][950]-40, 25000], sol.y[:, 10000:][:, 950], 
                             t_eval=np.array(range(sol.t[10000:][950], 25000, 2)), rtol = 1e-11, atol = 1e-11, dense_output=True)

# %%
plt.plot(smth.t, smth.y[0])

# %%
C = 0 
 
def FHN_correcting(t, X):    
        x1, y1, x2, y2 = X
        if (-t + (np.array(T_events) - 50) < 1e-4).sum() > 0:
        #if t == t_global-40:
            print(t)
            
            return [x1*(a-x1)*(x1-1) - y1 + k*(x2-x1) - 1,
                    b1*x1 - c*y1,
                    x2*(a-x2)*(x2-1) - y2 + k*(x1-x2),
                    b2*x2 - c*y2
                   ]
        
        return [x1*(a-x1)*(x1-1) - y1 + k*(x2-x1),
                    b1*x1 - c*y1,
                    x2*(a-x2)*(x2-1) - y2 + k*(x1-x2),
                    b2*x2 - c*y2
                   ]

# %%
T_events = []
i = 0
while i < len(test):
  if test[i] > 0.4:
    T_events.append(sol.t[10000:][i])
    i += 30
  i += 1

# %%
T_events

# %%
sol.t[10000:][940:970],test[940:970]

# %%
v = test[0]
new_data = sol.y[:, 10000:]
new_data_without_sup = sol.y[:, 10000:]
valid = []
predicted = []
rms = []
r = np.expand_dims(R[:, -1], axis=1)
r = reservoir_step(r, train_norm[-1])
t_global = 10002
M = 20
i = 0 
while i < len(new_data[0]):
    #if i%20 == 0 and i != 0:
        #rms.append((v-test[i])**2)
        #v = new_data[0, i] 
    r_loop = r
    v = (new_data[0][i] - mean)/std
    for m in range(M): 
        r_loop, v = predict(r_loop, v)
        if mean + v[0]*std > 0.2:
            print(m)
            new_data = solve_ivp(FHN_correcting, [t_global-40, 25000], new_data[:, i], 
                             t_eval=np.array(range(t_global, 25000, 2)), rtol = 1e-11, atol = 1e-11, dense_output=True).y
            new_data_without_sup = solve_ivp(FHN, [t_global-40, 25000], new_data_without_sup[:, i], 
                                          t_eval=np.array(range(t_global, 25000, 2)), rtol = 1e-11, atol = 1e-11, dense_output=True).y
            v = (new_data[0][0] - mean)/std
            i = 0
            break
    
    v = (new_data[0][i] - mean)/std 
    r = reservoir_step(r, v)
    predicted.append(mean + v*std)
    
    #r, v = predict(r, v)
    valid.append(new_data_without_sup[0][i])
    t_global += 2
    i += 1

# %%
plt.plot(predicted[:1000])

# %%
plt.plot(valid[:1000])

# %%
plt.plot( valid, c='r')
plt.plot( predicted)
